# %%
import numpy as np
import matplotlib.pyplot as plt
import vtk
import os

# %%
def rdp(points, epsilon):
    """
    Simplify a curve using the Ramer-Douglas-Peucker algorithm.

    Parameters:
    - points: List of (x, y) coordinates representing the curve.
    - epsilon: The maximum distance allowed between the original curve and the simplified curve.

    Returns:
    - List of simplified (x, y) coordinates.
    """
    if len(points) <= 2:
        return points

    # Find the point with the maximum distance
    dmax = 0
    index = 0
    end = len(points) - 1
    for i in range(1, end):
        d = np.linalg.norm(np.cross(
            np.array(points[end]) - np.array(points[0]),
            np.array(points[i]) - np.array(points[0])
        )) / np.linalg.norm(np.array(points[end]) - np.array(points[0]))

        if d > dmax:
            index = i
            dmax = d

    # If max distance is greater than epsilon, recursively simplify
    if dmax > epsilon:
        rec_results1 = rdp(points[:index+1], epsilon)
        rec_results2 = rdp(points[index:], epsilon)

        # Combine the results
        result = rec_results1[:-1] + rec_results2
    else:
        result = [points[0], points[end]]

    return result

# %%
def interpolar (centerline, epsilon = 0.05):

    resampleada = vtk.vtkPolyData()
    cellarray = vtk.vtkCellArray()
    points = vtk.vtkPoints()
    lista_puntos = []
    lista_rama = []
    for j in range(centerline.GetNumberOfCells()):#iterar por ramas  
        numberOfCellPoints = centerline.GetCell(j).GetNumberOfPoints();# number of points of the branch
        for i in range(numberOfCellPoints):
            originalPointId = centerline.GetCell(j).GetPointId(i)
            point = centerline.GetPoints().GetPoint(originalPointId)
            lista_puntos.append(list(point))
            
        #Ya tengo la lista de puntos de la rama entonces la resampleo y la agrego a la linea punto y polydata
        rama_resampleada = rdp(lista_puntos, epsilon)
        polyline = vtk.vtkPolyLine()
        for point in rama_resampleada:
            newPointId = points.InsertNextPoint(point)
            polyline.GetPointIds().InsertNextId(newPointId)
        cellarray.InsertNextCell(polyline)
        lista_rama.append(lista_puntos)
        lista_puntos = []
    resampleada.SetPoints(points)
    resampleada.SetLines(cellarray)
    return resampleada

# %%
centerlines = os.listdir("centerlines")
reader = vtk.vtkXMLPolyDataReader()
writer = vtk.vtkXMLPolyDataWriter()
for file in centerlines:
    if file not in os.listdir("resample_Eps01/centerlines/") and file.split(".")[1] == "vtp":
        print("calculando: ", file)
        reader.SetFileName("centerlines/" + file)
        reader.Update()
        # Get the polydata
        centerline = reader.GetOutput()
        resampleada = interpolar(centerline, 0.1)
        writer.SetFileName("resample_Eps01/centerlines/" + file)
        writer.SetInputData(resampleada)
        writer.Write()
# Out:
# calculando:  ArteryObjAN1-0-network.vtp
# calculando:  ArteryObjAN1-11-network.vtp
# calculando:  ArteryObjAN1-12-network.vtp
# calculando:  ArteryObjAN1-15-network.vtp
# calculando:  ArteryObjAN1-16-network.vtp
# calculando:  ArteryObjAN1-17-network.vtp
# calculando:  ArteryObjAN1-19-network.vtp
# calculando:  ArteryObjAN1-2-network.vtp
# calculando:  ArteryObjAN1-4-network.vtp
# calculando:  ArteryObjAN1-5-network.vtp
# calculando:  ArteryObjAN1-6-network.vtp
# calculando:  ArteryObjAN1-7-network.vtp
# calculando:  ArteryObjAN11-0-network.vtp
# calculando:  ArteryObjAN11-1-network.vtp
# calculando:  ArteryObjAN11-11-network.vtp
# calculando:  ArteryObjAN11-16-network.vtp
# calculando:  ArteryObjAN11-17-network.vtp
# calculando:  ArteryObjAN11-2-network.vtp
# calculando:  ArteryObjAN11-3-network.vtp
# calculando:  ArteryObjAN11-4-network.vtp
# calculando:  ArteryObjAN11-5-network.vtp
# calculando:  ArteryObjAN11-6-network.vtp
# calculando:  ArteryObjAN11-8-network.vtp
# calculando:  ArteryObjAN116-0-network.vtp
# calculando:  ArteryObjAN116-1-network.vtp
# calculando:  ArteryObjAN116-10-network.vtp
# calculando:  ArteryObjAN116-11-network.vtp
# calculando:  ArteryObjAN116-12-network.vtp
# calculando:  ArteryObjAN116-15-network.vtp
# calculando:  ArteryObjAN116-16-network.vtp
# calculando:  ArteryObjAN116-17-network.vtp
# calculando:  ArteryObjAN116-2-network.vtp
# calculando:  ArteryObjAN116-3-network.vtp
# calculando:  ArteryObjAN116-4-network.vtp
# calculando:  ArteryObjAN116-6-network.vtp
# calculando:  ArteryObjAN116-7-network.vtp
# calculando:  ArteryObjAN116-8-network.vtp
# calculando:  ArteryObjAN116-9-network.vtp
# calculando:  ArteryObjAN117-0-network.vtp
# calculando:  ArteryObjAN117-10-network.vtp
# calculando:  ArteryObjAN117-11-network.vtp
# calculando:  ArteryObjAN117-12-network.vtp
# calculando:  ArteryObjAN117-14-network.vtp
# calculando:  ArteryObjAN117-15-network.vtp
# calculando:  ArteryObjAN117-16-network.vtp
# calculando:  ArteryObjAN117-18-network.vtp
# calculando:  ArteryObjAN117-19-network.vtp
# calculando:  ArteryObjAN117-2-network.vtp
# calculando:  ArteryObjAN117-3-network.vtp
# calculando:  ArteryObjAN117-5-network.vtp
# calculando:  ArteryObjAN117-6-network.vtp
# calculando:  ArteryObjAN117-7-network.vtp
# calculando:  ArteryObjAN117-8-network.vtp
# calculando:  ArteryObjAN117-9-network.vtp
# calculando:  ArteryObjAN119-0-network.vtp
# calculando:  ArteryObjAN119-1-network.vtp
# calculando:  ArteryObjAN119-10-network.vtp
# calculando:  ArteryObjAN119-11-network.vtp
# calculando:  ArteryObjAN119-12-network.vtp
# calculando:  ArteryObjAN119-13-network.vtp
# calculando:  ArteryObjAN119-14-network.vtp
# calculando:  ArteryObjAN119-15-network.vtp
# calculando:  ArteryObjAN119-16-network.vtp
# calculando:  ArteryObjAN119-17-network.vtp
# calculando:  ArteryObjAN119-18-network.vtp
# calculando:  ArteryObjAN119-19-network.vtp
# calculando:  ArteryObjAN119-2-network.vtp
# calculando:  ArteryObjAN119-3-network.vtp
# calculando:  ArteryObjAN119-4-network.vtp
# calculando:  ArteryObjAN119-5-network.vtp
# calculando:  ArteryObjAN119-7-network.vtp
# calculando:  ArteryObjAN120-1-network.vtp
# calculando:  ArteryObjAN120-10-network.vtp
# calculando:  ArteryObjAN120-11-network.vtp
# calculando:  ArteryObjAN120-13-network.vtp
# calculando:  ArteryObjAN120-14-network.vtp
# calculando:  ArteryObjAN120-16-network.vtp
# calculando:  ArteryObjAN120-17-network.vtp
# calculando:  ArteryObjAN120-19-network.vtp
# calculando:  ArteryObjAN120-2-network.vtp
# calculando:  ArteryObjAN120-4-network.vtp
# calculando:  ArteryObjAN120-5-network.vtp
# calculando:  ArteryObjAN120-7-network.vtp
# calculando:  ArteryObjAN120-8-network.vtp
# calculando:  ArteryObjAN121-0-network.vtp
# calculando:  ArteryObjAN121-1-network.vtp
# calculando:  ArteryObjAN121-11-network.vtp
# calculando:  ArteryObjAN121-12-network.vtp
# calculando:  ArteryObjAN121-13-network.vtp
# calculando:  ArteryObjAN121-15-network.vtp
# calculando:  ArteryObjAN121-17-network.vtp
# calculando:  ArteryObjAN121-18-network.vtp
# calculando:  ArteryObjAN121-19-network.vtp
# calculando:  ArteryObjAN121-2-network.vtp
# calculando:  ArteryObjAN121-3-network.vtp
# calculando:  ArteryObjAN121-4-network.vtp
# calculando:  ArteryObjAN121-5-network.vtp
# calculando:  ArteryObjAN121-7-network.vtp
# calculando:  ArteryObjAN121-8-network.vtp
# calculando:  ArteryObjAN121-9-network.vtp
# calculando:  ArteryObjAN125-0-network.vtp
# calculando:  ArteryObjAN125-1-network.vtp
# calculando:  ArteryObjAN125-10-network.vtp
# calculando:  ArteryObjAN125-11-network.vtp
# calculando:  ArteryObjAN125-13-network.vtp
# calculando:  ArteryObjAN125-14-network.vtp
# calculando:  ArteryObjAN125-15-network.vtp
# calculando:  ArteryObjAN125-16-network.vtp
# calculando:  ArteryObjAN125-17-network.vtp
# calculando:  ArteryObjAN125-19-network.vtp
# calculando:  ArteryObjAN125-2-network.vtp
# calculando:  ArteryObjAN125-4-network.vtp
# calculando:  ArteryObjAN125-6-network.vtp
# calculando:  ArteryObjAN125-7-network.vtp
# calculando:  ArteryObjAN125-9-network.vtp
# calculando:  ArteryObjAN128-0-network.vtp
# calculando:  ArteryObjAN128-1-network.vtp
# calculando:  ArteryObjAN128-10-network.vtp
# calculando:  ArteryObjAN128-15-network.vtp
# calculando:  ArteryObjAN128-16-network.vtp
# calculando:  ArteryObjAN128-17-network.vtp
# calculando:  ArteryObjAN128-18-network.vtp
# calculando:  ArteryObjAN128-19-network.vtp
# calculando:  ArteryObjAN128-3-network.vtp
# calculando:  ArteryObjAN128-4-network.vtp
# calculando:  ArteryObjAN128-5-network.vtp
# calculando:  ArteryObjAN128-7-network.vtp
# calculando:  ArteryObjAN128-8-network.vtp
# calculando:  ArteryObjAN128-9-network.vtp
# calculando:  ArteryObjAN129-1-network.vtp
# calculando:  ArteryObjAN129-11-network.vtp
# calculando:  ArteryObjAN129-13-network.vtp
# calculando:  ArteryObjAN129-14-network.vtp
# calculando:  ArteryObjAN129-16-network.vtp
# calculando:  ArteryObjAN129-18-network.vtp
# calculando:  ArteryObjAN129-19-network.vtp
# calculando:  ArteryObjAN129-2-network.vtp
# calculando:  ArteryObjAN129-5-network.vtp
# calculando:  ArteryObjAN129-6-network.vtp
# calculando:  ArteryObjAN129-7-network.vtp
# calculando:  ArteryObjAN129-8-network.vtp
# calculando:  ArteryObjAN129-9-network.vtp
# calculando:  ArteryObjAN134-10-network.vtp
# calculando:  ArteryObjAN134-11-network.vtp
# calculando:  ArteryObjAN134-14-network.vtp
# calculando:  ArteryObjAN134-16-network.vtp
# calculando:  ArteryObjAN134-18-network.vtp
# calculando:  ArteryObjAN134-19-network.vtp
# calculando:  ArteryObjAN134-2-network.vtp
# calculando:  ArteryObjAN134-3-network.vtp
# calculando:  ArteryObjAN134-4-network.vtp
# calculando:  ArteryObjAN134-5-network.vtp
# calculando:  ArteryObjAN134-6-network.vtp
# calculando:  ArteryObjAN134-7-network.vtp
# calculando:  ArteryObjAN135-0-network.vtp
# calculando:  ArteryObjAN135-1-network.vtp
# calculando:  ArteryObjAN135-10-network.vtp
# calculando:  ArteryObjAN135-12-network.vtp
# calculando:  ArteryObjAN135-15-network.vtp
# calculando:  ArteryObjAN135-17-network.vtp
# calculando:  ArteryObjAN135-18-network.vtp
# calculando:  ArteryObjAN135-19-network.vtp
# calculando:  ArteryObjAN135-2-network.vtp
# calculando:  ArteryObjAN135-5-network.vtp
# calculando:  ArteryObjAN135-6-network.vtp
# calculando:  ArteryObjAN135-7-network.vtp
# calculando:  ArteryObjAN135-8-network.vtp
# calculando:  ArteryObjAN135-9-network.vtp
# calculando:  ArteryObjAN136-0-network.vtp
# calculando:  ArteryObjAN136-10-network.vtp
# calculando:  ArteryObjAN136-12-network.vtp
# calculando:  ArteryObjAN136-13-network.vtp
# calculando:  ArteryObjAN136-15-network.vtp
# calculando:  ArteryObjAN136-16-network.vtp
# calculando:  ArteryObjAN136-17-network.vtp
# calculando:  ArteryObjAN136-18-network.vtp
# calculando:  ArteryObjAN136-2-network.vtp
# calculando:  ArteryObjAN136-3-network.vtp
# calculando:  ArteryObjAN136-4-network.vtp
# calculando:  ArteryObjAN136-5-network.vtp
# calculando:  ArteryObjAN136-6-network.vtp
# calculando:  ArteryObjAN136-8-network.vtp
# calculando:  ArteryObjAN137-0-network.vtp
# calculando:  ArteryObjAN137-1-network.vtp
# calculando:  ArteryObjAN137-11-network.vtp
# calculando:  ArteryObjAN137-12-network.vtp
# calculando:  ArteryObjAN137-13-network.vtp
# calculando:  ArteryObjAN137-14-network.vtp
# calculando:  ArteryObjAN137-17-network.vtp
# calculando:  ArteryObjAN137-18-network.vtp
# calculando:  ArteryObjAN137-3-network.vtp
# calculando:  ArteryObjAN137-4-network.vtp
# calculando:  ArteryObjAN137-5-network.vtp
# calculando:  ArteryObjAN137-6-network.vtp
# calculando:  ArteryObjAN137-7-network.vtp
# calculando:  ArteryObjAN137-8-network.vtp
# calculando:  ArteryObjAN138-0-network.vtp
# calculando:  ArteryObjAN138-1-network.vtp
# calculando:  ArteryObjAN138-10-network.vtp
# calculando:  ArteryObjAN138-11-network.vtp
# calculando:  ArteryObjAN138-12-network.vtp
# calculando:  ArteryObjAN138-13-network.vtp
# calculando:  ArteryObjAN138-15-network.vtp
# calculando:  ArteryObjAN138-16-network.vtp
# calculando:  ArteryObjAN138-17-network.vtp
# calculando:  ArteryObjAN138-18-network.vtp
# calculando:  ArteryObjAN138-19-network.vtp
# calculando:  ArteryObjAN138-2-network.vtp
# calculando:  ArteryObjAN138-3-network.vtp
# calculando:  ArteryObjAN138-4-network.vtp
# calculando:  ArteryObjAN138-6-network.vtp
# calculando:  ArteryObjAN138-7-network.vtp
# calculando:  ArteryObjAN138-8-network.vtp
# calculando:  ArteryObjAN139-0-network.vtp
# calculando:  ArteryObjAN139-1-network.vtp
# calculando:  ArteryObjAN139-11-network.vtp
# calculando:  ArteryObjAN139-12-network.vtp
# calculando:  ArteryObjAN139-13-network.vtp
# calculando:  ArteryObjAN139-14-network.vtp
# calculando:  ArteryObjAN139-15-network.vtp
# calculando:  ArteryObjAN139-16-network.vtp
# calculando:  ArteryObjAN139-17-network.vtp
# calculando:  ArteryObjAN139-2-network.vtp
# calculando:  ArteryObjAN139-3-network.vtp
# calculando:  ArteryObjAN139-4-network.vtp
# calculando:  ArteryObjAN139-6-network.vtp
# calculando:  ArteryObjAN139-7-network.vtp
# calculando:  ArteryObjAN139-8-network.vtp
# calculando:  ArteryObjAN140-0-network.vtp
# calculando:  ArteryObjAN140-10-network.vtp
# calculando:  ArteryObjAN140-11-network.vtp
# calculando:  ArteryObjAN140-12-network.vtp
# calculando:  ArteryObjAN140-14-network.vtp
# calculando:  ArteryObjAN140-16-network.vtp
# calculando:  ArteryObjAN140-17-network.vtp
# calculando:  ArteryObjAN140-5-network.vtp
# calculando:  ArteryObjAN140-7-network.vtp
# calculando:  ArteryObjAN142-10-network.vtp
# calculando:  ArteryObjAN142-11-network.vtp
# calculando:  ArteryObjAN142-13-network.vtp
# calculando:  ArteryObjAN142-14-network.vtp
# calculando:  ArteryObjAN142-15-network.vtp
# calculando:  ArteryObjAN142-16-network.vtp
# calculando:  ArteryObjAN142-18-network.vtp
# calculando:  ArteryObjAN142-2-network.vtp
# calculando:  ArteryObjAN142-5-network.vtp
# calculando:  ArteryObjAN142-6-network.vtp
# calculando:  ArteryObjAN142-7-network.vtp
# calculando:  ArteryObjAN144-0-network.vtp
# calculando:  ArteryObjAN144-10-network.vtp
# calculando:  ArteryObjAN144-11-network.vtp
# calculando:  ArteryObjAN144-12-network.vtp
# calculando:  ArteryObjAN144-13-network.vtp
# calculando:  ArteryObjAN144-15-network.vtp
# calculando:  ArteryObjAN144-18-network.vtp
# calculando:  ArteryObjAN144-19-network.vtp
# calculando:  ArteryObjAN144-3-network.vtp
# calculando:  ArteryObjAN144-4-network.vtp
# calculando:  ArteryObjAN144-5-network.vtp
# calculando:  ArteryObjAN144-6-network.vtp
# calculando:  ArteryObjAN144-8-network.vtp
# calculando:  ArteryObjAN144-9-network.vtp
# calculando:  ArteryObjAN148-0-network.vtp
# calculando:  ArteryObjAN148-12-network.vtp
# calculando:  ArteryObjAN148-16-network.vtp
# calculando:  ArteryObjAN148-17-network.vtp
# calculando:  ArteryObjAN148-19-network.vtp
# calculando:  ArteryObjAN148-4-network.vtp
# calculando:  ArteryObjAN148-5-network.vtp
# calculando:  ArteryObjAN149-0-network.vtp
# calculando:  ArteryObjAN149-14-network.vtp
# calculando:  ArteryObjAN149-18-network.vtp
# calculando:  ArteryObjAN149-4-network.vtp
# calculando:  ArteryObjAN149-5-network.vtp
# calculando:  ArteryObjAN149-9-network.vtp
# calculando:  ArteryObjAN151-1-network.vtp
# calculando:  ArteryObjAN151-10-network.vtp
# calculando:  ArteryObjAN151-11-network.vtp
# calculando:  ArteryObjAN151-12-network.vtp
# calculando:  ArteryObjAN151-13-network.vtp
# calculando:  ArteryObjAN151-14-network.vtp
# calculando:  ArteryObjAN151-15-network.vtp
# calculando:  ArteryObjAN151-16-network.vtp
# calculando:  ArteryObjAN151-18-network.vtp
# calculando:  ArteryObjAN151-19-network.vtp
# calculando:  ArteryObjAN151-2-network.vtp
# calculando:  ArteryObjAN151-3-network.vtp
# calculando:  ArteryObjAN151-4-network.vtp
# calculando:  ArteryObjAN151-6-network.vtp
# calculando:  ArteryObjAN151-7-network.vtp
# calculando:  ArteryObjAN151-8-network.vtp
# calculando:  ArteryObjAN152-0-network.vtp
# calculando:  ArteryObjAN152-12-network.vtp
# calculando:  ArteryObjAN152-14-network.vtp
# calculando:  ArteryObjAN152-16-network.vtp
# calculando:  ArteryObjAN152-18-network.vtp
# calculando:  ArteryObjAN152-19-network.vtp
# calculando:  ArteryObjAN152-2-network.vtp
# calculando:  ArteryObjAN152-4-network.vtp
# calculando:  ArteryObjAN152-7-network.vtp
# calculando:  ArteryObjAN152-9-network.vtp
# calculando:  ArteryObjAN153-0-network.vtp
# calculando:  ArteryObjAN153-1-network.vtp
# calculando:  ArteryObjAN153-15-network.vtp
# calculando:  ArteryObjAN153-16-network.vtp
# calculando:  ArteryObjAN153-17-network.vtp
# calculando:  ArteryObjAN153-19-network.vtp
# calculando:  ArteryObjAN153-4-network.vtp
# calculando:  ArteryObjAN153-5-network.vtp
# calculando:  ArteryObjAN153-6-network.vtp
# calculando:  ArteryObjAN155-10-network.vtp
# calculando:  ArteryObjAN155-12-network.vtp
# calculando:  ArteryObjAN155-15-network.vtp
# calculando:  ArteryObjAN155-17-network.vtp
# calculando:  ArteryObjAN155-2-network.vtp
# calculando:  ArteryObjAN155-3-network.vtp
# calculando:  ArteryObjAN155-5-network.vtp
# calculando:  ArteryObjAN155-7-network.vtp
# calculando:  ArteryObjAN155-9-network.vtp
# calculando:  ArteryObjAN157-10-network.vtp
# calculando:  ArteryObjAN157-11-network.vtp
# calculando:  ArteryObjAN157-14-network.vtp
# calculando:  ArteryObjAN157-16-network.vtp
# calculando:  ArteryObjAN157-17-network.vtp
# calculando:  ArteryObjAN157-2-network.vtp
# calculando:  ArteryObjAN157-3-network.vtp
# calculando:  ArteryObjAN157-4-network.vtp
# calculando:  ArteryObjAN157-5-network.vtp
# calculando:  ArteryObjAN157-9-network.vtp
# calculando:  ArteryObjAN158-0-network.vtp
# calculando:  ArteryObjAN158-10-network.vtp
# calculando:  ArteryObjAN158-11-network.vtp
# calculando:  ArteryObjAN158-12-network.vtp
# calculando:  ArteryObjAN158-13-network.vtp
# calculando:  ArteryObjAN158-14-network.vtp
# calculando:  ArteryObjAN158-15-network.vtp
# calculando:  ArteryObjAN158-19-network.vtp
# calculando:  ArteryObjAN158-3-network.vtp
# calculando:  ArteryObjAN158-4-network.vtp
# calculando:  ArteryObjAN158-8-network.vtp
# calculando:  ArteryObjAN158-9-network.vtp
# calculando:  ArteryObjAN159-0-network.vtp
# calculando:  ArteryObjAN159-1-network.vtp
# calculando:  ArteryObjAN159-15-network.vtp
# calculando:  ArteryObjAN159-16-network.vtp
# calculando:  ArteryObjAN159-17-network.vtp
# calculando:  ArteryObjAN159-19-network.vtp
# calculando:  ArteryObjAN159-2-network.vtp
# calculando:  ArteryObjAN159-5-network.vtp
# calculando:  ArteryObjAN160-0-network.vtp
# calculando:  ArteryObjAN160-1-network.vtp
# calculando:  ArteryObjAN160-10-network.vtp
# calculando:  ArteryObjAN160-11-network.vtp
# calculando:  ArteryObjAN160-12-network.vtp
# calculando:  ArteryObjAN160-13-network.vtp
# calculando:  ArteryObjAN160-14-network.vtp
# calculando:  ArteryObjAN160-17-network.vtp
# calculando:  ArteryObjAN160-18-network.vtp
# calculando:  ArteryObjAN160-19-network.vtp
# calculando:  ArteryObjAN160-2-network.vtp
# calculando:  ArteryObjAN160-4-network.vtp
# calculando:  ArteryObjAN160-6-network.vtp
# calculando:  ArteryObjAN160-7-network.vtp
# calculando:  ArteryObjAN160-8-network.vtp
# calculando:  ArteryObjAN160-9-network.vtp
# calculando:  ArteryObjAN161-0-network.vtp
# calculando:  ArteryObjAN161-11-network.vtp
# calculando:  ArteryObjAN161-14-network.vtp
# calculando:  ArteryObjAN161-16-network.vtp
# calculando:  ArteryObjAN161-17-network.vtp
# calculando:  ArteryObjAN161-18-network.vtp
# calculando:  ArteryObjAN161-19-network.vtp
# calculando:  ArteryObjAN161-2-network.vtp
# calculando:  ArteryObjAN161-5-network.vtp
# calculando:  ArteryObjAN161-6-network.vtp
# calculando:  ArteryObjAN161-7-network.vtp
# calculando:  ArteryObjAN161-9-network.vtp
# calculando:  ArteryObjAN162-1-network.vtp
# calculando:  ArteryObjAN162-10-network.vtp
# calculando:  ArteryObjAN162-11-network.vtp
# calculando:  ArteryObjAN162-12-network.vtp
# calculando:  ArteryObjAN162-13-network.vtp
# calculando:  ArteryObjAN162-14-network.vtp
# calculando:  ArteryObjAN162-16-network.vtp
# calculando:  ArteryObjAN162-17-network.vtp
# calculando:  ArteryObjAN162-18-network.vtp
# calculando:  ArteryObjAN162-19-network.vtp
# calculando:  ArteryObjAN162-3-network.vtp
# calculando:  ArteryObjAN162-4-network.vtp
# calculando:  ArteryObjAN162-7-network.vtp
# calculando:  ArteryObjAN162-9-network.vtp
# calculando:  ArteryObjAN163-1-network.vtp
# calculando:  ArteryObjAN163-11-network.vtp
# calculando:  ArteryObjAN163-13-network.vtp
# calculando:  ArteryObjAN163-14-network.vtp
# calculando:  ArteryObjAN163-15-network.vtp
# calculando:  ArteryObjAN163-16-network.vtp
# calculando:  ArteryObjAN163-2-network.vtp
# calculando:  ArteryObjAN163-3-network.vtp
# calculando:  ArteryObjAN163-4-network.vtp
# calculando:  ArteryObjAN163-6-network.vtp
# calculando:  ArteryObjAN163-7-network.vtp
# calculando:  ArteryObjAN164-10-network.vtp
# calculando:  ArteryObjAN164-14-network.vtp
# calculando:  ArteryObjAN164-15-network.vtp
# calculando:  ArteryObjAN164-3-network.vtp
# calculando:  ArteryObjAN164-6-network.vtp
# calculando:  ArteryObjAN164-8-network.vtp
# calculando:  ArteryObjAN165-1-network.vtp
# calculando:  ArteryObjAN165-10-network.vtp
# calculando:  ArteryObjAN165-13-network.vtp
# calculando:  ArteryObjAN165-15-network.vtp
# calculando:  ArteryObjAN165-16-network.vtp
# calculando:  ArteryObjAN165-17-network.vtp
# calculando:  ArteryObjAN165-19-network.vtp
# calculando:  ArteryObjAN165-2-network.vtp
# calculando:  ArteryObjAN165-3-network.vtp
# calculando:  ArteryObjAN165-6-network.vtp
# calculando:  ArteryObjAN165-7-network.vtp
# calculando:  ArteryObjAN165-8-network.vtp
# calculando:  ArteryObjAN165-9-network.vtp
# calculando:  ArteryObjAN166-14-network.vtp
# calculando:  ArteryObjAN166-15-network.vtp
# calculando:  ArteryObjAN166-18-network.vtp
# calculando:  ArteryObjAN166-3-network.vtp
# calculando:  ArteryObjAN166-7-network.vtp
# calculando:  ArteryObjAN167-0-network.vtp
# calculando:  ArteryObjAN167-11-network.vtp
# calculando:  ArteryObjAN167-13-network.vtp
# calculando:  ArteryObjAN167-15-network.vtp
# calculando:  ArteryObjAN167-16-network.vtp
# calculando:  ArteryObjAN167-17-network.vtp
# calculando:  ArteryObjAN167-19-network.vtp
# calculando:  ArteryObjAN167-2-network.vtp
# calculando:  ArteryObjAN167-3-network.vtp
# calculando:  ArteryObjAN167-4-network.vtp
# calculando:  ArteryObjAN167-5-network.vtp
# calculando:  ArteryObjAN167-7-network.vtp
# calculando:  ArteryObjAN167-8-network.vtp
# calculando:  ArteryObjAN168-0-network.vtp
# calculando:  ArteryObjAN168-10-network.vtp
# calculando:  ArteryObjAN168-13-network.vtp
# calculando:  ArteryObjAN168-16-network.vtp
# calculando:  ArteryObjAN168-17-network.vtp
# calculando:  ArteryObjAN168-19-network.vtp
# calculando:  ArteryObjAN168-2-network.vtp
# calculando:  ArteryObjAN168-3-network.vtp
# calculando:  ArteryObjAN168-7-network.vtp
# calculando:  ArteryObjAN168-8-network.vtp
# calculando:  ArteryObjAN170-1-network.vtp
# calculando:  ArteryObjAN170-11-network.vtp
# calculando:  ArteryObjAN170-13-network.vtp
# calculando:  ArteryObjAN170-14-network.vtp
# calculando:  ArteryObjAN170-16-network.vtp
# calculando:  ArteryObjAN170-18-network.vtp
# calculando:  ArteryObjAN170-5-network.vtp
# calculando:  ArteryObjAN170-6-network.vtp
# calculando:  ArteryObjAN170-8-network.vtp
# calculando:  ArteryObjAN170-9-network.vtp
# calculando:  ArteryObjAN171-0-network.vtp
# calculando:  ArteryObjAN171-11-network.vtp
# calculando:  ArteryObjAN171-12-network.vtp
# calculando:  ArteryObjAN171-13-network.vtp
# calculando:  ArteryObjAN171-14-network.vtp
# calculando:  ArteryObjAN171-15-network.vtp
# calculando:  ArteryObjAN171-17-network.vtp
# calculando:  ArteryObjAN171-18-network.vtp
# calculando:  ArteryObjAN171-19-network.vtp
# calculando:  ArteryObjAN171-2-network.vtp
# calculando:  ArteryObjAN171-3-network.vtp
# calculando:  ArteryObjAN171-4-network.vtp
# calculando:  ArteryObjAN171-5-network.vtp
# calculando:  ArteryObjAN171-6-network.vtp
# calculando:  ArteryObjAN171-9-network.vtp
# calculando:  ArteryObjAN172-10-network.vtp
# calculando:  ArteryObjAN172-12-network.vtp
# calculando:  ArteryObjAN172-13-network.vtp
# calculando:  ArteryObjAN172-15-network.vtp
# calculando:  ArteryObjAN172-16-network.vtp
# calculando:  ArteryObjAN172-19-network.vtp
# calculando:  ArteryObjAN172-2-network.vtp
# calculando:  ArteryObjAN172-3-network.vtp
# calculando:  ArteryObjAN172-4-network.vtp
# calculando:  ArteryObjAN172-6-network.vtp
# calculando:  ArteryObjAN172-7-network.vtp
# calculando:  ArteryObjAN172-8-network.vtp
# calculando:  ArteryObjAN172-9-network.vtp
# calculando:  ArteryObjAN173-0-network.vtp
# calculando:  ArteryObjAN173-1-network.vtp
# calculando:  ArteryObjAN173-12-network.vtp
# calculando:  ArteryObjAN173-13-network.vtp
# calculando:  ArteryObjAN173-16-network.vtp
# calculando:  ArteryObjAN173-2-network.vtp
# calculando:  ArteryObjAN173-4-network.vtp
# calculando:  ArteryObjAN173-5-network.vtp
# calculando:  ArteryObjAN173-6-network.vtp
# calculando:  ArteryObjAN174-1-network.vtp
# calculando:  ArteryObjAN174-15-network.vtp
# calculando:  ArteryObjAN174-17-network.vtp
# calculando:  ArteryObjAN174-2-network.vtp
# calculando:  ArteryObjAN174-8-network.vtp
# calculando:  ArteryObjAN174-9-network.vtp
# calculando:  ArteryObjAN175-0-network.vtp
# calculando:  ArteryObjAN175-14-network.vtp
# calculando:  ArteryObjAN175-15-network.vtp
# calculando:  ArteryObjAN175-17-network.vtp
# calculando:  ArteryObjAN175-3-network.vtp
# calculando:  ArteryObjAN175-5-network.vtp
# calculando:  ArteryObjAN175-6-network.vtp
# calculando:  ArteryObjAN175-8-network.vtp
# calculando:  ArteryObjAN175-9-network.vtp
# calculando:  ArteryObjAN177-10-network.vtp
# calculando:  ArteryObjAN177-11-network.vtp
# calculando:  ArteryObjAN177-16-network.vtp
# calculando:  ArteryObjAN177-19-network.vtp
# calculando:  ArteryObjAN177-3-network.vtp
# calculando:  ArteryObjAN177-4-network.vtp
# calculando:  ArteryObjAN177-6-network.vtp
# calculando:  ArteryObjAN177-9-network.vtp
# calculando:  ArteryObjAN178-12-network.vtp
# calculando:  ArteryObjAN178-15-network.vtp
# calculando:  ArteryObjAN178-16-network.vtp
# calculando:  ArteryObjAN178-18-network.vtp
# calculando:  ArteryObjAN178-4-network.vtp
# calculando:  ArteryObjAN178-9-network.vtp
# calculando:  ArteryObjAN180-12-network.vtp
# calculando:  ArteryObjAN180-14-network.vtp
# calculando:  ArteryObjAN180-17-network.vtp
# calculando:  ArteryObjAN180-2-network.vtp
# calculando:  ArteryObjAN180-5-network.vtp
# calculando:  ArteryObjAN181-10-network.vtp
# calculando:  ArteryObjAN181-11-network.vtp
# calculando:  ArteryObjAN181-13-network.vtp
# calculando:  ArteryObjAN181-15-network.vtp
# calculando:  ArteryObjAN181-17-network.vtp
# calculando:  ArteryObjAN181-18-network.vtp
# calculando:  ArteryObjAN181-19-network.vtp
# calculando:  ArteryObjAN181-2-network.vtp
# calculando:  ArteryObjAN181-3-network.vtp
# calculando:  ArteryObjAN181-8-network.vtp
# calculando:  ArteryObjAN181-9-network.vtp
# calculando:  ArteryObjAN182-0-network.vtp
# calculando:  ArteryObjAN182-1-network.vtp
# calculando:  ArteryObjAN182-13-network.vtp
# calculando:  ArteryObjAN182-14-network.vtp
# calculando:  ArteryObjAN182-15-network.vtp
# calculando:  ArteryObjAN182-16-network.vtp
# calculando:  ArteryObjAN182-17-network.vtp
# calculando:  ArteryObjAN182-19-network.vtp
# calculando:  ArteryObjAN182-6-network.vtp
# calculando:  ArteryObjAN182-8-network.vtp
# calculando:  ArteryObjAN182-9-network.vtp
# calculando:  ArteryObjAN183-1-network.vtp
# calculando:  ArteryObjAN183-10-network.vtp
# calculando:  ArteryObjAN183-11-network.vtp
# calculando:  ArteryObjAN183-12-network.vtp
# calculando:  ArteryObjAN183-13-network.vtp
# calculando:  ArteryObjAN183-14-network.vtp
# calculando:  ArteryObjAN183-15-network.vtp
# calculando:  ArteryObjAN183-17-network.vtp
# calculando:  ArteryObjAN183-18-network.vtp
# calculando:  ArteryObjAN183-19-network.vtp
# calculando:  ArteryObjAN183-2-network.vtp
# calculando:  ArteryObjAN183-3-network.vtp
# calculando:  ArteryObjAN183-5-network.vtp
# calculando:  ArteryObjAN183-6-network.vtp
# calculando:  ArteryObjAN183-7-network.vtp
# calculando:  ArteryObjAN183-8-network.vtp
# calculando:  ArteryObjAN185-0-network.vtp
# calculando:  ArteryObjAN185-1-network.vtp
# calculando:  ArteryObjAN185-10-network.vtp
# calculando:  ArteryObjAN185-11-network.vtp
# calculando:  ArteryObjAN185-12-network.vtp
# calculando:  ArteryObjAN185-13-network.vtp
# calculando:  ArteryObjAN185-14-network.vtp
# calculando:  ArteryObjAN185-15-network.vtp
# calculando:  ArteryObjAN185-16-network.vtp
# calculando:  ArteryObjAN185-17-network.vtp
# calculando:  ArteryObjAN185-18-network.vtp
# calculando:  ArteryObjAN185-2-network.vtp
# calculando:  ArteryObjAN185-3-network.vtp
# calculando:  ArteryObjAN185-4-network.vtp
# calculando:  ArteryObjAN185-6-network.vtp
# calculando:  ArteryObjAN185-7-network.vtp
# calculando:  ArteryObjAN185-8-network.vtp
# calculando:  ArteryObjAN185-9-network.vtp
# calculando:  ArteryObjAN186-14-network.vtp
# calculando:  ArteryObjAN186-16-network.vtp
# calculando:  ArteryObjAN186-17-network.vtp
# calculando:  ArteryObjAN186-2-network.vtp
# calculando:  ArteryObjAN186-3-network.vtp
# calculando:  ArteryObjAN186-4-network.vtp
# calculando:  ArteryObjAN186-6-network.vtp
# calculando:  ArteryObjAN186-7-network.vtp
# calculando:  ArteryObjAN187-1-network.vtp
# calculando:  ArteryObjAN187-10-network.vtp
# calculando:  ArteryObjAN187-13-network.vtp
# calculando:  ArteryObjAN187-14-network.vtp
# calculando:  ArteryObjAN187-15-network.vtp
# calculando:  ArteryObjAN187-19-network.vtp
# calculando:  ArteryObjAN187-2-network.vtp
# calculando:  ArteryObjAN187-5-network.vtp
# calculando:  ArteryObjAN187-6-network.vtp
# calculando:  ArteryObjAN187-7-network.vtp
# calculando:  ArteryObjAN187-9-network.vtp
# calculando:  ArteryObjAN188-0-network.vtp
# calculando:  ArteryObjAN188-10-network.vtp
# calculando:  ArteryObjAN188-13-network.vtp
# calculando:  ArteryObjAN188-14-network.vtp
# calculando:  ArteryObjAN188-16-network.vtp
# calculando:  ArteryObjAN188-5-network.vtp
# calculando:  ArteryObjAN188-9-network.vtp
# calculando:  ArteryObjAN19-0-network.vtp
# calculando:  ArteryObjAN19-1-network.vtp
# calculando:  ArteryObjAN19-10-network.vtp
# calculando:  ArteryObjAN19-11-network.vtp
# calculando:  ArteryObjAN19-13-network.vtp
# calculando:  ArteryObjAN19-14-network.vtp
# calculando:  ArteryObjAN19-15-network.vtp
# calculando:  ArteryObjAN19-16-network.vtp
# calculando:  ArteryObjAN19-17-network.vtp
# calculando:  ArteryObjAN19-19-network.vtp
# calculando:  ArteryObjAN19-3-network.vtp
# calculando:  ArteryObjAN19-5-network.vtp
# calculando:  ArteryObjAN19-6-network.vtp
# calculando:  ArteryObjAN19-7-network.vtp
# calculando:  ArteryObjAN2-1-network.vtp
# calculando:  ArteryObjAN2-10-network.vtp
# calculando:  ArteryObjAN2-11-network.vtp
# calculando:  ArteryObjAN2-14-network.vtp
# calculando:  ArteryObjAN2-19-network.vtp
# calculando:  ArteryObjAN2-2-network.vtp
# calculando:  ArteryObjAN2-4-network.vtp
# calculando:  ArteryObjAN2-5-network.vtp
# calculando:  ArteryObjAN2-6-network.vtp
# calculando:  ArteryObjAN2-7-network.vtp
# calculando:  ArteryObjAN2-8-network.vtp
# calculando:  ArteryObjAN2-9-network.vtp
# calculando:  ArteryObjAN23-0-network.vtp
# calculando:  ArteryObjAN23-10-network.vtp
# calculando:  ArteryObjAN23-14-network.vtp
# calculando:  ArteryObjAN23-16-network.vtp
# calculando:  ArteryObjAN23-19-network.vtp
# calculando:  ArteryObjAN23-4-network.vtp
# calculando:  ArteryObjAN23-6-network.vtp
# calculando:  ArteryObjAN23-7-network.vtp
# calculando:  ArteryObjAN23-8-network.vtp
# calculando:  ArteryObjAN23-9-network.vtp
# calculando:  ArteryObjAN25-0-network.vtp
# calculando:  ArteryObjAN25-1-network.vtp
# calculando:  ArteryObjAN25-10-network.vtp
# calculando:  ArteryObjAN25-11-network.vtp
# calculando:  ArteryObjAN25-12-network.vtp
# calculando:  ArteryObjAN25-13-network.vtp
# calculando:  ArteryObjAN25-15-network.vtp
# calculando:  ArteryObjAN25-16-network.vtp
# calculando:  ArteryObjAN25-17-network.vtp
# calculando:  ArteryObjAN25-18-network.vtp
# calculando:  ArteryObjAN25-19-network.vtp
# calculando:  ArteryObjAN25-2-network.vtp
# calculando:  ArteryObjAN25-3-network.vtp
# calculando:  ArteryObjAN25-6-network.vtp
# calculando:  ArteryObjAN25-7-network.vtp
# calculando:  ArteryObjAN25-8-network.vtp
# calculando:  ArteryObjAN26-0-network.vtp
# calculando:  ArteryObjAN26-1-network.vtp
# calculando:  ArteryObjAN26-10-network.vtp
# calculando:  ArteryObjAN26-12-network.vtp
# calculando:  ArteryObjAN26-13-network.vtp
# calculando:  ArteryObjAN26-14-network.vtp
# calculando:  ArteryObjAN26-16-network.vtp
# calculando:  ArteryObjAN26-17-network.vtp
# calculando:  ArteryObjAN26-19-network.vtp
# calculando:  ArteryObjAN26-2-network.vtp
# calculando:  ArteryObjAN26-3-network.vtp
# calculando:  ArteryObjAN26-4-network.vtp
# calculando:  ArteryObjAN26-5-network.vtp
# calculando:  ArteryObjAN26-6-network.vtp
# calculando:  ArteryObjAN26-7-network.vtp
# calculando:  ArteryObjAN26-8-network.vtp
# calculando:  ArteryObjAN26-9-network.vtp
# calculando:  ArteryObjAN27-12-network.vtp
# calculando:  ArteryObjAN27-13-network.vtp
# calculando:  ArteryObjAN27-16-network.vtp
# calculando:  ArteryObjAN27-18-network.vtp
# calculando:  ArteryObjAN27-3-network.vtp
# calculando:  ArteryObjAN27-4-network.vtp
# calculando:  ArteryObjAN27-5-network.vtp
# calculando:  ArteryObjAN27-6-network.vtp
# calculando:  ArteryObjAN28-10-network.vtp
# calculando:  ArteryObjAN28-11-network.vtp
# calculando:  ArteryObjAN28-12-network.vtp
# calculando:  ArteryObjAN28-14-network.vtp
# calculando:  ArteryObjAN28-16-network.vtp
# calculando:  ArteryObjAN28-17-network.vtp
# calculando:  ArteryObjAN28-18-network.vtp
# calculando:  ArteryObjAN28-2-network.vtp
# calculando:  ArteryObjAN28-3-network.vtp
# calculando:  ArteryObjAN28-4-network.vtp
# calculando:  ArteryObjAN28-5-network.vtp
# calculando:  ArteryObjAN28-6-network.vtp
# calculando:  ArteryObjAN28-7-network.vtp
# calculando:  ArteryObjAN28-9-network.vtp
# calculando:  ArteryObjAN3-12-network.vtp
# calculando:  ArteryObjAN3-13-network.vtp
# calculando:  ArteryObjAN3-15-network.vtp
# calculando:  ArteryObjAN3-17-network.vtp
# calculando:  ArteryObjAN3-2-network.vtp
# calculando:  ArteryObjAN3-4-network.vtp
# calculando:  ArteryObjAN3-6-network.vtp
# calculando:  ArteryObjAN3-7-network.vtp
# calculando:  ArteryObjAN3-8-network.vtp
# calculando:  ArteryObjAN31-0-network.vtp
# calculando:  ArteryObjAN31-1-network.vtp
# calculando:  ArteryObjAN31-11-network.vtp
# calculando:  ArteryObjAN31-14-network.vtp
# calculando:  ArteryObjAN31-16-network.vtp
# calculando:  ArteryObjAN31-18-network.vtp
# calculando:  ArteryObjAN31-4-network.vtp
# calculando:  ArteryObjAN31-8-network.vtp
# calculando:  ArteryObjAN31-9-network.vtp
# calculando:  ArteryObjAN32-10-network.vtp
# calculando:  ArteryObjAN32-13-network.vtp
# calculando:  ArteryObjAN32-14-network.vtp
# calculando:  ArteryObjAN32-15-network.vtp
# calculando:  ArteryObjAN32-16-network.vtp
# calculando:  ArteryObjAN32-17-network.vtp
# calculando:  ArteryObjAN32-18-network.vtp
# calculando:  ArteryObjAN32-19-network.vtp
# calculando:  ArteryObjAN32-5-network.vtp
# calculando:  ArteryObjAN32-6-network.vtp
# calculando:  ArteryObjAN32-9-network.vtp
# calculando:  ArteryObjAN34-0-network.vtp
# calculando:  ArteryObjAN34-11-network.vtp
# calculando:  ArteryObjAN34-12-network.vtp
# calculando:  ArteryObjAN34-15-network.vtp
# calculando:  ArteryObjAN34-16-network.vtp
# calculando:  ArteryObjAN34-18-network.vtp
# calculando:  ArteryObjAN34-19-network.vtp
# calculando:  ArteryObjAN34-2-network.vtp
# calculando:  ArteryObjAN34-3-network.vtp
# calculando:  ArteryObjAN34-4-network.vtp
# calculando:  ArteryObjAN34-6-network.vtp
# calculando:  ArteryObjAN34-8-network.vtp
# calculando:  ArteryObjAN40-10-network.vtp
# calculando:  ArteryObjAN40-11-network.vtp
# calculando:  ArteryObjAN40-13-network.vtp
# calculando:  ArteryObjAN40-14-network.vtp
# calculando:  ArteryObjAN40-15-network.vtp
# calculando:  ArteryObjAN40-16-network.vtp
# calculando:  ArteryObjAN40-17-network.vtp
# calculando:  ArteryObjAN40-18-network.vtp
# calculando:  ArteryObjAN40-19-network.vtp
# calculando:  ArteryObjAN40-3-network.vtp
# calculando:  ArteryObjAN40-4-network.vtp
# calculando:  ArteryObjAN40-5-network.vtp
# calculando:  ArteryObjAN40-6-network.vtp
# calculando:  ArteryObjAN40-7-network.vtp
# calculando:  ArteryObjAN40-8-network.vtp
# calculando:  ArteryObjAN42-0-network.vtp
# calculando:  ArteryObjAN42-1-network.vtp
# calculando:  ArteryObjAN42-13-network.vtp
# calculando:  ArteryObjAN42-14-network.vtp
# calculando:  ArteryObjAN42-15-network.vtp
# calculando:  ArteryObjAN42-16-network.vtp
# calculando:  ArteryObjAN42-17-network.vtp
# calculando:  ArteryObjAN42-4-network.vtp
# calculando:  ArteryObjAN42-5-network.vtp
# calculando:  ArteryObjAN42-7-network.vtp
# calculando:  ArteryObjAN42-9-network.vtp
# calculando:  ArteryObjAN44-10-network.vtp
# calculando:  ArteryObjAN44-11-network.vtp
# calculando:  ArteryObjAN44-13-network.vtp
# calculando:  ArteryObjAN44-15-network.vtp
# calculando:  ArteryObjAN44-17-network.vtp
# calculando:  ArteryObjAN44-18-network.vtp
# calculando:  ArteryObjAN44-2-network.vtp
# calculando:  ArteryObjAN44-3-network.vtp
# calculando:  ArteryObjAN44-4-network.vtp
# calculando:  ArteryObjAN44-5-network.vtp
# calculando:  ArteryObjAN44-6-network.vtp
# calculando:  ArteryObjAN44-8-network.vtp
# calculando:  ArteryObjAN44-9-network.vtp
# calculando:  ArteryObjAN54-12-network.vtp
# calculando:  ArteryObjAN54-4-network.vtp
# calculando:  ArteryObjAN54-5-network.vtp
# calculando:  ArteryObjAN55-1-network.vtp
# calculando:  ArteryObjAN55-10-network.vtp
# calculando:  ArteryObjAN55-11-network.vtp
# calculando:  ArteryObjAN55-12-network.vtp
# calculando:  ArteryObjAN55-13-network.vtp
# calculando:  ArteryObjAN55-14-network.vtp
# calculando:  ArteryObjAN55-15-network.vtp
# calculando:  ArteryObjAN55-16-network.vtp
# calculando:  ArteryObjAN55-18-network.vtp
# calculando:  ArteryObjAN55-19-network.vtp
# calculando:  ArteryObjAN55-2-network.vtp
# calculando:  ArteryObjAN55-3-network.vtp
# calculando:  ArteryObjAN55-4-network.vtp
# calculando:  ArteryObjAN55-5-network.vtp
# calculando:  ArteryObjAN55-6-network.vtp
# calculando:  ArteryObjAN55-8-network.vtp
# calculando:  ArteryObjAN55-9-network.vtp
# calculando:  ArteryObjAN58-0-network.vtp
# calculando:  ArteryObjAN58-1-network.vtp
# calculando:  ArteryObjAN58-10-network.vtp
# calculando:  ArteryObjAN58-11-network.vtp
# calculando:  ArteryObjAN58-12-network.vtp
# calculando:  ArteryObjAN58-14-network.vtp
# calculando:  ArteryObjAN58-15-network.vtp
# calculando:  ArteryObjAN58-16-network.vtp
# calculando:  ArteryObjAN58-17-network.vtp
# calculando:  ArteryObjAN58-19-network.vtp
# calculando:  ArteryObjAN58-2-network.vtp
# calculando:  ArteryObjAN58-3-network.vtp
# calculando:  ArteryObjAN58-4-network.vtp
# calculando:  ArteryObjAN58-5-network.vtp
# calculando:  ArteryObjAN58-6-network.vtp
# calculando:  ArteryObjAN58-7-network.vtp
# calculando:  ArteryObjAN58-8-network.vtp
# calculando:  ArteryObjAN6-0-network.vtp
# calculando:  ArteryObjAN6-12-network.vtp
# calculando:  ArteryObjAN6-14-network.vtp
# calculando:  ArteryObjAN6-15-network.vtp
# calculando:  ArteryObjAN6-19-network.vtp
# calculando:  ArteryObjAN6-2-network.vtp
# calculando:  ArteryObjAN6-3-network.vtp
# calculando:  ArteryObjAN6-4-network.vtp
# calculando:  ArteryObjAN6-7-network.vtp
# calculando:  ArteryObjAN6-8-network.vtp
# calculando:  ArteryObjAN9-0-network.vtp
# calculando:  ArteryObjAN9-12-network.vtp
# calculando:  ArteryObjAN9-13-network.vtp
# calculando:  ArteryObjAN9-14-network.vtp
# calculando:  ArteryObjAN9-18-network.vtp
# calculando:  ArteryObjAN9-19-network.vtp
# calculando:  ArteryObjAN9-2-network.vtp
# calculando:  ArteryObjAN9-3-network.vtp
# calculando:  ArteryObjAN9-4-network.vtp
# calculando:  ArteryObjAN9-5-network.vtp
# calculando:  ArteryObjAN9-6-network.vtp
# calculando:  ArteryObjAN9-7-network.vtp
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
